# %%
# !rm -rf WAN-2.1-Working
# !rm -rf data
# !rm -rf outputs
# !rm -rf samples

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
# Hugging Face + Diffusers nightly setup
# !pip install -U git+https://github.com/huggingface/diffusers.git
# !pip install -U transformers peft accelerate safetensors einops imageio[ffmpeg] tqdm huggingface_hub

# Clone your repo
# !git clone https://github.com/md1789/WAN-2.1-Working.git
# %cd WAN-2.1-Working

from google.colab import drive
drive.mount('/content/drive')

# (Optional) Kaggle setup: upload kaggle.json in Colab’s left file browser (/content/)
# !mkdir -p ~/.kaggle
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# !cat ~/.kaggle/kaggle.json

# Download the dataset
# !python scripts/prepare_kaggle.py --dataset sharjeelmazhar/human-activity-recognition-video-dataset --out data/har
# Out:
# ...
#   Cloning https://github.com/huggingface/diffusers.git to /tmp/pip-req-build-jdzxf53x
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers.git /tmp/pip-req-build-jdzxf53x
#   Resolved https://github.com/huggingface/diffusers.git to commit d34b18c783a772a0f9b24b7da7b834d785b5e58f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# Cloning into 'WAN-2.1-Working'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 57 (delta 22), reused 47 (delta 12), pack-reused 0 (from 0)
# Receiving objects: 100% (57/57), 18.19 KiB | 18.19 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
# /content/WAN-2.1-Working
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...

# %%
# Train LoRA (dummy loop runs even without WAN backbone)
# !python train_lora.py --config configs/lora_wan21_har.yaml
# Out:
# 2025-10-26 03:37:57.351816: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-26 03:37:57.386463: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761449877.410097   90708 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761449877.423845   90708 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Generate example videos
# !python generate_videos.py --config configs/infer_har.yaml

# %%
import yaml
with open("configs/lora_wan21_har.yaml") as f:
    cfg = yaml.safe_load(f)
print(cfg["model"]["base_ckpt"])
# Out:
# TencentARC/WanT2V
